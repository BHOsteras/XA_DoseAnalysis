# %% [markdown]
# # Script XA DSA
# This notebook imports necessary libraries and data from Excel files to work with ...

# %%
import dt_ids7_export_module as bh_utils
import mapping_module as bh_map
import plot_module as bh_plot

# Get the name of the computer:
import socket
hostname = socket.gethostname()
if hostname == 'BHs-Desktop':
    path = 'C:\\' # 'E:\\'
elif hostname == 'BH-XPS':
    path = 'G:\\'
else:
    path = ''


# Import the IDS7 data:
root_folder = path + "/run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/"
df_ids7 = bh_utils.import_excel_files_to_dataframe(root_folder)

# Import the IDS7 data:
root_folder = path + "/run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/"
df_dt = bh_utils.import_excel_files_to_dataframe(root_folder)
# Out:
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-01 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-09 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-05 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-11 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-06 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-08 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-03 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-10 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-02 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-12 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-04 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2024/2024-07 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-01 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-09 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-05 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-11 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-06 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-08 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-03 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-10 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-02 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-12 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-04 - OUS.xlsx...
# Reading /run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2024/2024-07 - OUS.xlsx...

# %%
# Run all cleanups, filters and checks:
df_ids7 = bh_utils.run_all_cleanup_filters_and_checks(df_ids7, df_dt, True)
# Merge the dataframes:
data = bh_utils.merge_ids7_dt(df_ids7, df_dt, True)
# Out:
# Dropping unnecessary column: Prioritet- og lesemerkeikon
# Dropping unnecessary column: Lagt til i demonstrasjon-ikon
# Dropping unnecessary column: Status
# Number of rows with NaT in the column "Bestilt dato og tidspunkt": 1530
# Number of cancelled procedures: 295
# Number of non-human subjects: 101
# Number of rows with invalid accession number: 7
# 2211     NNRA000009433721
# 15276    NNUL000009507772
# 15277    NNUL000009507772
# 15278    NNUL000009612281
# 22573    NBOU000012935221
# 33617    NNRA000009532398
# 33618    NNRA000009578608
# Name: Henvisnings-ID, dtype: object
# Number of accession numbers in IDS7: 21339
# Number of accession numbers in IDS7 not in DoseTrack: 2591
# WARNING: The column "Pasient" does not exist in the "IDS7" dataframe.
# Without this column, we cannot keep track of which procedures are on the same patient.
#
#
# User Guide to get the "Pasienter" column in the IDS7 data:
#
#
# Note that the "Pasient column is not a column in IDS7, but must be created manually for anonymity reasons.
# This can be done in excel after export to a safe location using the following method:
# Copy the personal ID's from the column Fødelsnummer to a new column.
# Then mark the new column and click the data fan -> "Fjern Duplikater"
# Next to this column write for instance: "PAS0001"
# Then doubleclick the small square in the bottom right corner of the cell to autofill.
# This will create a unique identifier for each patient.
# Make a new blank column next to the Fødselsnummer column, and fill it with the new anonymized patient ID.
# Use the =FINN.RAD() function in excel. First argument is the Fødselsnr
# The second argument is the matrix of the unique fødselsnr and the anonymized patient ID (remember $-signs)
# The third argument is the column number of the anonymized patient ID in the matrix: 2
# The fourth argument is USANN
# Finally, copy the annonymized column into a new column named "Pasient" and remember to paste as numbers.
# Make sure to delete the column "Fødselsnummer" and the key-matrix of the unique Fødselsnummer and the anonymized patient ID.
# Then save the file.
#
#
# Number of accession numbers in DoseTrack: 19456
# Number of accession numbers in DoseTrack not in IDS7: 708
# WARNING: The column "Pasient" does not exist in the "IDS7" dataframe.
# This column will not be included in the merged data.
#
#
# The IDS7 and DoseTrack has merged data of length: 18748

# %%
# Print all unique elements in Modality Room, sorted alphabetically:
print("Unique elements in Modality Room:")
print(sorted(data['Modality Room'].unique()))

# %%
import mapping_dict_rad_xa as rad_dict
# Representative doser for radiologisk Rikshospital
data = data[data['Modality Room'].isin(['IRH_XA7', 'RAK_XA1', 'RRA_XA1', 'RRH_RF1', 'RRH_RF2', 'RRH_XA1', 'RRH_XA2', 'RRH_XA4', 'RUL_RF1', 'RUL_RF2', 'RUL_RF3', 'RUL_XA3', 'RUL_XA5', 'RUL_XA6', 'RUL_XA7(Stue 15)'])]
import importlib
importlib.reload(rad_dict)


# Get the mapping dictionary:
mapping_dict = rad_dict.get_rad_xa_mapping_dict()
data = bh_map.map_procedures(data, mapping_dict, True)

# %%
procedure = 'Caput Embolisering'
export = False
bh_plot.plot_representative_dose(data, procedure, 200, export)

# %%
procedure = 'Trombektomi'
bh_plot.plot_representative_dose(data, procedure, 200, export)

# %%
procedure = 'Caput og collum'
bh_plot.plot_representative_dose(data, procedure, 200, export)

# %%
procedure = 'Myelografi'
bh_plot.plot_representative_dose(data, procedure, 175, export)

# %%
procedure = 'Vertebroplastikk'
bh_plot.plot_representative_dose(data, procedure, 100, export)

# %%
procedure = 'RG Columna eks. Myelografi og vertebroplastikk'
bh_plot.plot_representative_dose(data, procedure, 40, export)

# %%
procedure = 'Cervical Nerverotsinjeksjon'
bh_plot.plot_representative_dose(data, procedure, 25, export)

# %%
procedure = 'Cochlia'
bh_plot.plot_representative_dose(data, procedure, 10, export)

# %%
procedure = 'Scoliose'
bh_plot.plot_representative_dose(data, procedure, 10, export)

# %%
procedure = 'Shuntveier/Shuntventil'
bh_plot.plot_representative_dose(data, procedure, 35, export)

# %%
procedure = 'Diafragmabevegelse'
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'HSG'
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Svelgfunksjon'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Øsofagus/ØVD, eks. svelgfunksjon'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Nedleggelse av ventrikkelsonde'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Urethragrafi/Urografi/Urinveier/MUCG'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Defecografi'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Gastroskopi'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Videofluoroskopi'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Nefrostomi innleggelse'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Nefrostomi/Pyelografi skifte eller fjerning'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'TACE'
export = False
bh_plot.plot_representative_dose(data, procedure, 200, export)

# %%
procedure = 'PTC/PTBD/ERCP'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'RG Galleblære u. PTC eller Galleveier'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'BEVAR/FEVAR'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'TEVAR'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'EVAR'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Abdomen/Bekken/Aorta PTA/Embolisering/Stent/Stentgraft'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Milt/Nyrer'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'RG Abdomen - Abscessografi, Fjerning/Skifte av dren'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Pulmonalarterier/PTA/Embolisering'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'RGV Thorax'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Lymfangiografi'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Underex'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)

# %%
procedure = 'Overex'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)
