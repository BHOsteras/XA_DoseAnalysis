# %% [markdown]
# # Script XA DSA
# This notebook imports necessary libraries and data from Excel files to work with ...

# %%
from xa_dose_analysis import dt_ids7_export_module as bh_utils
from xa_dose_analysis import mapping_module as bh_map
from xa_dose_analysis import plot_module as bh_plot
import pandas as pd



# Import the DoseTrack data:
root_folder = "/run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/DoseTrack - Serienivå/2025/"
df_dt = bh_utils.import_excel_files_to_dataframe(root_folder)

# Import the IDS7 data:
root_folder = "/run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/IDS7/2025/"
df_ids7 = bh_utils.import_excel_files_to_dataframe(root_folder)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from xa_dose_analysis import dt_ids7_export_module as bh_utils
#       2 from xa_dose_analysis import mapping_module as bh_map
#       3 from xa_dose_analysis import plot_module as bh_plot
#
# ModuleNotFoundError: No module named 'xa_dose_analysis'

# %%
# Run all cleanups, filters and checks:
df_ids7 = bh_utils.run_all_cleanup_filters_and_checks(df_ids7, df_dt, True)
# Merge the dataframes:
data = bh_utils.merge_ids7_dt(df_ids7, df_dt, True)

# %%
data['Modality Room'].unique()

# %%
# Import the pkl file:
import pandas as pd
data = pd.read_pickle("/run/media/bhosteras/PRIVATE_USB/Intervensjon Doser/data/data_elfys_2025.pkl")

# %%
from xa_dose_analysis import dt_ids7_export_module as bh_utils
from xa_dose_analysis import mapping_module as bh_map
from xa_dose_analysis import plot_module as bh_plot
import pandas as pd
import xa_dose_analysis.mapping_dicts.mapping_dict_elfys as elfys_dict
# Representative doser for radiologisk Rikshospital
data = data[data['Modality Room'].isin(['KRH_Elfys1', 'KRH_Elfys2', 'KRH_Elfys3', 'KRH_Elfys4', 'KRH_Elfys5', 'KRH_Elfys1062', 'KRH_LAB39', 'KRH_Lab13'])]
import importlib
importlib.reload(elfys_dict)


# Get the mapping dictionary:
mapping_dict = elfys_dict.get_elfys_mapping_dict()
data = bh_map.map_procedures(data, mapping_dict, True)
# Out:
# Mapping procedures...
#
# RGA Cor Ablasjon SVT (int.) -> RGA Cor Ablasjon SVT (int.) m og u 3D
# RGA Cor Ablasjon SVT m 3D (int.) -> RGA Cor Ablasjon SVT (int.) m og u 3D
# RGA Cor Ablasjon VT m 3D (int.) & ~RGA Cor Ablasjon SVT -> RGA Cor Ablasjon VT (int.) m 3D
# RGA Cor Ablasjon Atrieflimmer (int.) -> RGA Cor Ablasjon Atrieflimmer (int.) m og u 3D
# WARNING! No procedures were targeted by this mapping!
#
#
# RGA Cor Ablasjon Atrieflimmer med 3D (int.) -> RGA Cor Ablasjon Atrieflimmer (int.) m og u 3D
# RGA Cor Pulsed field ablasjon (elektroporasjon) atrieflimmer -> RGA Cor Pulsed field ablasjon (elektroporasjon) atrieflimmer
# RGA Cor Cryo Ablasjon Atrieflimmer (int.) -> RGA Cor Cryo Ablasjon Atrieflimmer (int.)
# RGA Cor Ablasjon Atrieflutter (int.) & ~Atrieflimmer -> RGA Cor Ablasjon Atrieflutter (int.) m og u 3D
# RGA Cor Elfys SVT (int.) & ~Ablasjon & ~Atrieflutter -> RGA Cor Elfys VT el. SVT (int.)
# RGA Cor Elfys VT (int.) -> RGA Cor Elfys VT el. SVT (int.)
# RGA Cor CRT-D (int.) -> RGA Cor CRT-D (int.) ink. CRT-P
# RGA Cor CRT-P (int.) -> RGA Cor CRT-D (int.) ink. CRT-P
# RGA Cor 2-k PM (int.) -> RGA Cor Implantasjon PM/ICD (int.) ink. 2k og 1k PM
# RGA Cor 1-k PM (int.) -> RGA Cor Implantasjon PM/ICD (int.) ink. 2k og 1k PM
# RGA Cor 2-K ICD (int.) -> RGA Cor Implantasjon PM/ICD (int.) ink. 2k og 1k PM
# RGA Cor 1-k ICD (int.) -> RGA Cor Implantasjon PM/ICD (int.) ink. 2k og 1k PM
# RGA Cor Implantasjon PM/ICD (int.) & ~CRT -> RGA Cor Implantasjon PM/ICD (int.) ink. 2k og 1k PM
# WARNING! No procedures were targeted by this mapping!
#
#
# RGV Cor Biopsi høyre ventrikkel -> RGV Cor Biopsi
# RGV Cor Hø kat, måling av trykk og flow i lille kretsløp & ~RGV Cor Biopsi høyre ventrikkel -> RGV Cor Hø kat, måling av trykk og flow i lille kretsløp
# RGV Cor Høyre kat. Arytmi & ~RGV Cor Biopsi høyre ventrikkel -> RGV Cor Høyre kat. Arytmi

# %%
procedure = 'RGA Cor Ablasjon SVT (int.) m og u 3D'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)
# Out:
# Reporting doses for RGA Cor Ablasjon SVT (int.) m og u 3D:
#
#
# Alle: n =  358, DAP: Median - 2.2, 95% CI: [1.92 - 2.6] IQR [1.1 - 4.7], Range (0.0 - 56.3).
# Alle: n =  358, CAK: Median - 40.6, 95% CI: [34.52 - 49.51] IQR [15.5 - 83.0], Range (0.1 - 686.0).
#
#
# KRH_Elfys1: n =   62, DAP: Median - 2.26 (Gy*cm2), 95% CI: [1.64 - 3.11] IQR [1.17 - 4.24], Range (0.27 - 33.08).
# KRH_Elfys1062: n =  114, DAP: Median - 2.82 (Gy*cm2), 95% CI: [2.18 - 3.14] IQR [1.36 - 5.44], Range (0.44 - 29.25).
# KRH_Elfys2: n =   18, DAP: Median - 1.72 (Gy*cm2), 95% CI: [1.33 - 4.58] IQR [1.3 - 4.84], Range (0.72 - 7.32).
# KRH_Elfys3: n =  149, DAP: Median - 1.83 (Gy*cm2), 95% CI: [1.52 - 2.2] IQR [0.83 - 4.56], Range (0.02 - 56.28).
# KRH_Elfys4: n =   15, DAP: Median - 1.44 (Gy*cm2), 95% CI: [0.7 - 3.02] IQR [0.47 - 2.94], Range (0.09 - 4.78).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor Ablasjon VT (int.) m 3D'
bh_plot.plot_representative_dose(data, procedure, 20, export)
# Out:
# Reporting doses for RGA Cor Ablasjon VT (int.) m 3D:
#
#
# Alle: n =  134, DAP: Median - 3.1, 95% CI: [2.15 - 4.15] IQR [1.2 - 7.4], Range (0.2 - 70.4).
# Alle: n =  134, CAK: Median - 32.6, 95% CI: [23.44 - 40.75] IQR [13.0 - 72.3], Range (1.7 - 2280.9).
#
#
# KRH_Elfys1: n =   78, DAP: Median - 3.69 (Gy*cm2), 95% CI: [2.24 - 5.39] IQR [1.29 - 6.79], Range (0.2 - 70.37).
# KRH_Elfys2: n =    7, DAP: Median - 1.46 (Gy*cm2), 95% CI: [0.86 - 4.27] IQR [0.96 - 3.66], Range (0.67 - 11.9).
# KRH_Elfys3: n =   41, DAP: Median - 3.0 (Gy*cm2), 95% CI: [1.62 - 4.29] IQR [1.37 - 8.53], Range (0.47 - 53.57).
# KRH_Elfys4: n =    8, DAP: Median - 1.93 (Gy*cm2), 95% CI: [0.31 - 22.45] IQR [0.48 - 9.22], Range (0.26 - 22.91).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor Ablasjon Atrieflimmer (int.) m og u 3D'
export = False
bh_plot.plot_representative_dose(data, procedure, 30, export)
# Out:
# Reporting doses for RGA Cor Ablasjon Atrieflimmer (int.) m og u 3D:
#
#
# Alle: n =  239, DAP: Median - 2.9, 95% CI: [2.57 - 3.46] IQR [1.6 - 6.0], Range (0.2 - 87.1).
# Alle: n =  239, CAK: Median - 34.1, 95% CI: [30.63 - 41.36] IQR [16.5 - 61.5], Range (1.7 - 743.9).
#
#
# KRH_Elfys1: n =   54, DAP: Median - 2.92 (Gy*cm2), 95% CI: [2.24 - 4.21] IQR [1.84 - 5.93], Range (0.54 - 24.25).
# KRH_Elfys2: n =  115, DAP: Median - 3.28 (Gy*cm2), 95% CI: [2.67 - 4.15] IQR [2.02 - 5.71], Range (0.17 - 19.7).
# KRH_Elfys3: n =   29, DAP: Median - 1.9 (Gy*cm2), 95% CI: [1.41 - 7.14] IQR [1.22 - 12.23], Range (0.24 - 87.08).
# KRH_Elfys4: n =   40, DAP: Median - 1.8 (Gy*cm2), 95% CI: [1.35 - 3.5] IQR [0.91 - 5.24], Range (0.18 - 40.42).
# KRH_Elfys5: n =    1, DAP: Median - 6.04 (Gy*cm2), 95% CI: [6.04 - 6.04] IQR [6.04 - 6.04], Range (6.04 - 6.04).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor Pulsed field ablasjon (elektroporasjon) atrieflimmer'
bh_plot.plot_representative_dose(data, procedure, 20, export)
# Out:
# Reporting doses for RGA Cor Pulsed field ablasjon (elektroporasjon) atrieflimmer:
#
#
# Alle: n =   44, DAP: Median - 7.4, 95% CI: [5.8 - 8.56] IQR [4.8 - 9.4], Range (1.8 - 19.8).
# Alle: n =   44, CAK: Median - 73.2, 95% CI: [58.74 - 86.1] IQR [50.4 - 91.8], Range (18.4 - 194.7).
#
#
# KRH_Elfys1: n =   42, DAP: Median - 7.6 (Gy*cm2), 95% CI: [5.96 - 8.7] IQR [5.11 - 9.42], Range (1.91 - 19.82).
# KRH_Elfys2: n =    2, DAP: Median - 3.05 (Gy*cm2), 95% CI: [1.78 - 4.32] IQR [2.41 - 3.69], Range (1.78 - 4.32).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor Cryo Ablasjon Atrieflimmer (int.)'
bh_plot.plot_representative_dose(data, procedure, 40, export)
# Out:
# Reporting doses for RGA Cor Cryo Ablasjon Atrieflimmer (int.):
#
#
# Alle: n =  170, DAP: Median - 6.4, 95% CI: [5.44 - 7.11] IQR [3.4 - 10.6], Range (0.0 - 54.0).
# Alle: n =  170, CAK: Median - 65.7, 95% CI: [56.02 - 74.5] IQR [32.9 - 107.6], Range (0.0 - 592.9).
#
#
# KRH_Elfys1: n =   15, DAP: Median - 8.99 (Gy*cm2), 95% CI: [4.81 - 13.92] IQR [5.11 - 14.75], Range (2.38 - 54.0).
# KRH_Elfys2: n =  125, DAP: Median - 6.59 (Gy*cm2), 95% CI: [5.8 - 7.28] IQR [4.05 - 10.58], Range (0.0 - 27.64).
# KRH_Elfys3: n =    3, DAP: Median - 11.13 (Gy*cm2), 95% CI: [5.59 - 27.93] IQR [8.36 - 19.53], Range (5.59 - 27.93).
# KRH_Elfys4: n =   27, DAP: Median - 3.09 (Gy*cm2), 95% CI: [2.42 - 4.04] IQR [2.27 - 4.7], Range (0.69 - 36.52).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor Ablasjon Atrieflutter (int.) m og u 3D'
bh_plot.plot_representative_dose(data, procedure, 25, export)
# Out:
# Reporting doses for RGA Cor Ablasjon Atrieflutter (int.) m og u 3D:
#
#
# Alle: n =  183, DAP: Median - 3.3, 95% CI: [2.95 - 4.06] IQR [2.0 - 6.6], Range (0.0 - 33.9).
# Alle: n =  183, CAK: Median - 82.3, 95% CI: [73.25 - 91.66] IQR [53.0 - 133.3], Range (0.1 - 468.1).
#
#
# KRH_Elfys1: n =   26, DAP: Median - 3.23 (Gy*cm2), 95% CI: [2.24 - 5.05] IQR [2.1 - 6.05], Range (0.75 - 16.61).
# KRH_Elfys1062: n =   79, DAP: Median - 3.28 (Gy*cm2), 95% CI: [2.64 - 4.35] IQR [2.0 - 5.91], Range (0.85 - 33.95).
# KRH_Elfys2: n =   13, DAP: Median - 3.26 (Gy*cm2), 95% CI: [2.37 - 6.77] IQR [2.37 - 6.77], Range (0.6 - 33.54).
# KRH_Elfys3: n =   50, DAP: Median - 3.84 (Gy*cm2), 95% CI: [3.01 - 6.61] IQR [2.15 - 8.24], Range (0.02 - 22.54).
# KRH_Elfys4: n =   15, DAP: Median - 2.57 (Gy*cm2), 95% CI: [0.58 - 4.58] IQR [0.82 - 5.07], Range (0.14 - 12.02).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor Elfys VT el. SVT (int.)'
bh_plot.plot_representative_dose(data, procedure, 10, export)
# Out:
# Reporting doses for RGA Cor Elfys VT el. SVT (int.):
#
#
# Alle: n =  112, DAP: Median - 1.1, 95% CI: [0.8 - 1.42] IQR [0.5 - 2.1], Range (0.1 - 21.2).
# Alle: n =  112, CAK: Median - 13.2, 95% CI: [9.31 - 18.6] IQR [6.2 - 31.4], Range (1.4 - 392.0).
#
#
# KRH_Elfys1: n =   30, DAP: Median - 0.52 (Gy*cm2), 95% CI: [0.39 - 1.56] IQR [0.37 - 1.8], Range (0.1 - 21.22).
# KRH_Elfys1062: n =   49, DAP: Median - 1.27 (Gy*cm2), 95% CI: [0.82 - 1.76] IQR [0.74 - 2.05], Range (0.16 - 11.8).
# KRH_Elfys2: n =    6, DAP: Median - 0.97 (Gy*cm2), 95% CI: [0.3 - 5.85] IQR [0.34 - 4.0], Range (0.29 - 6.87).
# KRH_Elfys3: n =   22, DAP: Median - 1.03 (Gy*cm2), 95% CI: [0.7 - 1.49] IQR [0.65 - 2.12], Range (0.3 - 12.05).
# KRH_Elfys4: n =    5, DAP: Median - 2.34 (Gy*cm2), 95% CI: [0.26 - 5.0] IQR [1.24 - 2.44], Range (0.26 - 5.0).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor CRT-D (int.) ink. CRT-P'
bh_plot.plot_representative_dose(data, procedure, 35, export)
# Out:
# Reporting doses for RGA Cor CRT-D (int.) ink. CRT-P:
#
#
# Alle: n =   99, DAP: Median - 15.2, 95% CI: [11.11 - 18.36] IQR [7.7 - 25.7], Range (0.4 - 153.1).
# Alle: n =   99, CAK: Median - 65.9, 95% CI: [50.7 - 89.24] IQR [35.1 - 134.8], Range (3.9 - 722.3).
#
#
# KRH_Elfys4: n =   36, DAP: Median - 6.29 (Gy*cm2), 95% CI: [4.09 - 10.52] IQR [3.0 - 13.43], Range (0.39 - 80.1).
# KRH_Elfys5: n =    3, DAP: Median - 20.34 (Gy*cm2), 95% CI: [13.66 - 37.92] IQR [17.0 - 29.13], Range (13.66 - 37.92).
# KRH_Lab13: n =   60, DAP: Median - 19.36 (Gy*cm2), 95% CI: [15.65 - 24.74] IQR [11.35 - 34.72], Range (1.71 - 153.11).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGA Cor Implantasjon PM/ICD (int.) ink. 2k og 1k PM'
bh_plot.plot_representative_dose(data, procedure, 20, export)
# Out:
# Reporting doses for RGA Cor Implantasjon PM/ICD (int.) ink. 2k og 1k PM:
#
#
# Alle: n =   85, DAP: Median - 3.4, 95% CI: [2.33 - 4.48] IQR [1.2 - 8.2], Range (0.0 - 41.6).
# Alle: n =   85, CAK: Median - 12.3, 95% CI: [9.51 - 16.8] IQR [6.2 - 41.5], Range (0.2 - 140.2).
#
#
# KRH_Elfys3: n =    7, DAP: Median - 0.35 (Gy*cm2), 95% CI: [0.15 - 9.18] IQR [0.19 - 7.48], Range (0.05 - 9.98).
# KRH_Elfys4: n =   31, DAP: Median - 1.25 (Gy*cm2), 95% CI: [0.68 - 2.72] IQR [0.51 - 4.7], Range (0.04 - 12.57).
# KRH_Elfys5: n =    5, DAP: Median - 8.24 (Gy*cm2), 95% CI: [1.35 - 30.81] IQR [4.21 - 30.19], Range (1.35 - 30.81).
# KRH_Lab13: n =   42, DAP: Median - 3.99 (Gy*cm2), 95% CI: [3.13 - 5.51] IQR [2.44 - 9.4], Range (0.9 - 41.64).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
bh_report.print_summary(data)
bh_plot.plot_representative_dose_by_procedure(data[data!='Unmapped'])

# %%
procedure = 'RGV Cor Biopsi'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)
# Out:
# Reporting doses for RGV Cor Biopsi:
#
#
# Alle: n =  163, DAP: Median - 1.6, 95% CI: [1.27 - 1.75] IQR [0.9 - 2.6], Range (0.4 - 8.9).
# Alle: n =  163, CAK: Median - 5.8, 95% CI: [4.97 - 6.55] IQR [3.5 - 9.8], Range (1.4 - 33.7).
#
#
# KRH_Elfys5: n =  163, DAP: Median - 1.55 (Gy*cm2), 95% CI: [1.27 - 1.75] IQR [0.93 - 2.62], Range (0.37 - 8.93).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGV Cor Hø kat, måling av trykk og flow i lille kretsløp'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)
# Out:
# Reporting doses for RGV Cor Hø kat, måling av trykk og flow i lille kretsløp:
#
#
# Alle: n =    2, DAP: Median - 1.8, 95% CI: [1.36 - 2.29] IQR [1.6 - 2.1], Range (1.4 - 2.3).
# Alle: n =    2, CAK: Median - 7.1, 95% CI: [5.32 - 8.93] IQR [6.2 - 8.0], Range (5.3 - 8.9).
#
#
# KRH_Elfys5: n =    2, DAP: Median - 1.83 (Gy*cm2), 95% CI: [1.36 - 2.29] IQR [1.59 - 2.06], Range (1.36 - 2.29).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)

# %%
procedure = 'RGV Cor Høyre kat. Arytmi'
export = False
bh_plot.plot_representative_dose(data, procedure, 20, export)
# Out:
# Reporting doses for RGV Cor Høyre kat. Arytmi:
#
#
# Alle: n =  310, DAP: Median - 1.6, 95% CI: [1.38 - 1.86] IQR [0.8 - 3.4], Range (0.0 - 24.9).
# Alle: n =  310, CAK: Median - 6.2, 95% CI: [5.43 - 7.18] IQR [3.0 - 12.6], Range (0.0 - 99.8).
#
#
# KRH_Elfys2: n =    1, DAP: Median - 1.09 (Gy*cm2), 95% CI: [1.09 - 1.09] IQR [1.09 - 1.09], Range (1.09 - 1.09).
# KRH_Elfys5: n =  309, DAP: Median - 1.6 (Gy*cm2), 95% CI: [1.38 - 1.86] IQR [0.77 - 3.39], Range (0.01 - 24.85).
# --------------------------------------------------
# /home/bhosteras/Kode/XA_DoseAnalysis/src/xa_dose_analysis/plot_module.py:252: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   _ = ax.set_xticklabels(labels)
